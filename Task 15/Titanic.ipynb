# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# Most important factor to determine survival would be class of people.

# %%
df =pd.read_csv("Titanic.csv")
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df.sort_values("Sex")
# Out:
#      PassengerId  Survived  Pclass  \
# 383          384         1       1
# 218          219         1       1
# 609          610         1       1
# 216          217         1       3
# 215          216         1       1
# ..           ...       ...     ...
# 371          372         0       3
# 372          373         0       3
# 373          374         0       1
# 360          361         0       3
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 383  Holverson, Mrs. Alexander Oskar (Mary Aline To...  female  35.0      1
# 218                              Bazzani, Miss. Albina  female  32.0      0
# 609                          Shutes, Miss. Elizabeth W  female  40.0      0
# 216                             Honkanen, Miss. Eliina  female  27.0      0
# 215                            Newell, Miss. Madeleine  female  31.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
sns.pairplot(df, hue= 'Pclass')

# %% [markdown]
# Finding if the film showing upper class had priority on lifeboats is true to real life

# %%
# Counting the amount of people of each class
sns.countplot(x="Pclass", data =df)
plt.xlabel("Pclass")
plt.title("Count of people in each class")
# Out:
# Text(0.5, 1.0, 'Count of people in each class')

# %%
# Counting the amount of people who survived
sns.countplot(x="Survived", data =df)
plt.xlabel("Survived")
plt.title("Count of people who survived")
# Out:
# Text(0.5, 1.0, 'Count of people who survived')

# %%
correlation =df[["Pclass","Survived"]].corr()
print(correlation)
# Out:
#             Pclass  Survived
# Pclass    1.000000 -0.338481
# Survived -0.338481  1.000000

# %%
fig = plt.figure(figsize=(20, 10))
sns.histplot(df.loc[Surv['Pclass'] == 1]['Survived'])
sns.histplot(df.loc[Surv['Pclass'] == 2]['Survived'])
sns.histplot(df.loc[Surv['Pclass'] == 3]['Survived'])
# Out:
# <Axes: xlabel='Survived', ylabel='Count'>

# %% [markdown]
# The histogram above shows the count of each class that survived the titanic shipwreck. The blue bar is first class, the orange bar is second class and the green bar is third class. You can tell that the more of the first class survived than didn't which is what the film shows.

# %% [markdown]
# Finding if woman and children were off the boat first. If they were, they'd have a higher survival rate than men. Finding age for the children, under 18 is a child. Using male vs female for the women.
# A count plot needs to be used to show all the ages in the titanic dataset.

# %%
fig = plt.figure(figsize=(30, 10))
sns.countplot(x="Age", data =df)
plt.xlabel("Age")
plt.title("The age of people on board the Titanic")
# Out:
# Text(0.5, 1.0, 'The age of people on board the Titanic')

# %%
df.dropna()
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 10            11         1       3
# 11            12         1       1
# ..           ...       ...     ...
# 871          872         1       1
# 872          873         0       1
# 879          880         1       1
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 10                     Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# Ages need to be grouped into smaller groups of 10 for a better countplot. Max age is 80

# %%
df['Age_group'] = pd.cut(df['Age'], [0,9,19,29,39,49,59,69,79,89], 
                   labels=['0-9','10-19','20-29','30-39','40-49','50-59','60-69','70-79',
                           '80-89'])

fig = plt.figure(figsize=(20,10))
sns.countplot(y=df['Age_group'], data=df)
# Out:
# <Axes: xlabel='count', ylabel='Age_group'>

# %%
fig = plt.figure(figsize=(20, 10))
sns.histplot(df.loc[df['Age'] == 1]['Survived'])
sns.histplot(df.loc[df['Age'] == 2]['Survived'])
sns.histplot(df.loc[df['Age'] == 3]['Survived'])
sns.histplot(df.loc[df['Age'] == 4]['Survived'])
sns.histplot(df.loc[df['Age'] == 5]['Survived'])
sns.histplot(df.loc[df['Age'] == 6]['Survived'])
sns.histplot(df.loc[df['Age'] == 7]['Survived'])
sns.histplot(df.loc[df['Age'] == 8]['Survived'])
sns.histplot(df.loc[df['Age'] == 9]['Survived'])
# Out:
# <Axes: xlabel='Survived', ylabel='Count'>

# %% [markdown]
# The histogram above shows that between the ages of 0-18 or children survived more than adults.

# %%
sns.countplot(x="Sex", data =df)
plt.xlabel("Sex")
plt.title("The sex of people on board the Titanic")
# Out:
# Text(0.5, 1.0, 'The sex of people on board the Titanic')

# %%
fig = plt.figure(figsize=(20, 10))
sns.histplot(df.loc[df['Survived'] == 1]['Sex'])
sns.histplot(df.loc[df['Survived'] == 2]['Sex'])
# Out:
# <Axes: xlabel='Sex', ylabel='Count'>

# %% [markdown]
# The histogram above shows that more woman were first off the boat

# %% [markdown]
# Age vs fare charge

# %%
fig = plt.figure(figsize=(20, 10))
sns.histplot(df.loc[df['Age'] == 1]['Fare'])
sns.histplot(df.loc[df['Age'] == 2]['Fare'])
sns.histplot(df.loc[df['Age'] == 3]['Fare'])
sns.histplot(df.loc[df['Age'] == 4]['Fare'])
sns.histplot(df.loc[df['Age'] == 5]['Fare'])
sns.histplot(df.loc[df['Age'] == 6]['Fare'])
sns.histplot(df.loc[df['Age'] == 7]['Fare'])
sns.histplot(df.loc[df['Age'] == 8]['Fare'])
sns.histplot(df.loc[df['Age'] == 9]['Fare'])
# Out:
# <Axes: xlabel='Fare', ylabel='Count'>

# %% [markdown]
# The histogram above shows that older people paid less than younger people.
